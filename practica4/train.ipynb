# %% [markdown]
# En este Script se entrena un modelo con los conjuntos de datos train y test anteriores, y se guardan gráficos sobre dicho proceso, para analizar el rendimiento.
#
# Primero, debemos importar las librerías necesarias.

# %%
import os
from ultralytics import YOLO

# %%
cwd = os.getcwd()
DATASET_PATH = os.path.join(cwd, "dataset")

models_to_train = ["yolo11n-cls.pt", "yolo11s-cls.pt", "yolo11m-cls.pt"]

EPOCHS = 30         # Número de pasadas por el dataset
IMGSZ = 224         # Tamaño de imagen
BATCH_SIZE = 16     
PATIENCE = 10       # Detener si no mejora tras 10 épocas
PROJECT_NAME = "runs" # Carpeta donde se guardarán los resultados

# %%
for model_name in models_to_train:
    run_name = f'train_{model_name}'
    
    print(f"\n\n-------------------Modelo: {model_name}-------------------\n")
    
    model = YOLO(model_name) # Cargamos el modelo
    
    model.train(
        data=DATASET_PATH,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=BATCH_SIZE,
        patience=PATIENCE, 
        project=PROJECT_NAME, # Crea la ruta: runs/train_n/ por ejemplo
        name=run_name,
        device=0, # Utilizamos la GPU
        verbose=True
    )
# Out:
# -------------------Modelo: yolo11n-cls.pt-------------------
#
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n-cls.pt to 'yolo11n-cls.pt': 100% ━━━━━━━━━━━━ 5.5MB 22.1MB/s 0.2s.2s<0.0s
# Ultralytics 8.3.237 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce GTX 1660 Ti, 6144MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/dataset, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train_yolo11n-cls.pt, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/runs/train_yolo11n-cls.pt, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/dataset/train... found 800 images in 8 classes ✅
# val: None...
# test: /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/dataset/test... found 80 images in 8 classes ✅
# Overriding model.yaml nc=80 with nc=8
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  10                  -1  1    340488  ultralytics.nn.modules.head.Classify         [256, 8]
# YOLO11n-cls summary: 86 layers, 1,541,352 parameters, 1,541,352 gradients, 3.3 GFLOPs
# Transferred 234/236 items from pretrained weights
# WARNING ⚠️ AMP: checks failed ❌. AMP training on NVIDIA GeForce GTX 1660 Ti GPU may cause NaN losses or zero-mAP results, so AMP will be disabled during training.
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 305.2±77.5 MB/s, size: 240.3 KB)
# train: Scanning /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/dataset/train... 800 images, 0 corrupt: 100% ━━━━━━━━━━━━ 800/800 1.5Mit/s 0.0s0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 298.6±61.7 MB/s, size: 419.6 KB)
# val: Scanning /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/dataset/test... 80 images, 0 corrupt: 100% ━━━━━━━━━━━━ 80/80 42.4Kit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000833, momentum=0.9) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 8 dataloader workers
# Logging results to /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/runs/train_yolo11n-cls.pt
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/30     0.396G      2.095         16        224: 100% ━━━━━━━━━━━━ 50/50 6.0it/s 8.3s<0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 24.7it/s 0.1s.2s
#                    all      0.538        0.9
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/30      0.43G      1.671         16        224: 100% ━━━━━━━━━━━━ 50/50 16.1it/s 3.1s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 30.8it/s 0.1s
#                    all        0.5       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/30      0.43G       1.45         16        224: 100% ━━━━━━━━━━━━ 50/50 18.0it/s 2.8s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 44.2it/s 0.1s
#                    all      0.575      0.975
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/30     0.439G       1.36         16        224: 100% ━━━━━━━━━━━━ 50/50 18.0it/s 2.8s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 42.4it/s 0.1s
#                    all      0.625      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/30     0.447G      1.254         16        224: 100% ━━━━━━━━━━━━ 50/50 19.5it/s 2.6s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 47.6it/s 0.1s
#                    all      0.637      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/30     0.447G      1.158         16        224: 100% ━━━━━━━━━━━━ 50/50 19.3it/s 2.6s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 56.0it/s 0.1s
#                    all      0.613      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/30     0.447G      1.145         16        224: 100% ━━━━━━━━━━━━ 50/50 18.2it/s 2.8s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 49.6it/s 0.1s
#                    all      0.575       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/30     0.447G      1.054         16        224: 100% ━━━━━━━━━━━━ 50/50 16.7it/s 3.0s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 53.2it/s 0.1s
#                    all      0.637       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/30     0.457G      1.017         16        224: 100% ━━━━━━━━━━━━ 50/50 18.5it/s 2.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 58.1it/s 0.1s
#                    all      0.587       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/30     0.457G     0.8955         16        224: 100% ━━━━━━━━━━━━ 50/50 18.1it/s 2.8s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 56.1it/s 0.1s
#                    all        0.6      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/30     0.457G     0.8649         16        224: 100% ━━━━━━━━━━━━ 50/50 19.2it/s 2.6s0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 54.2it/s 0.1s
#                    all       0.65       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/30     0.457G      0.835         16        224: 100% ━━━━━━━━━━━━ 50/50 19.7it/s 2.5s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 50.9it/s 0.1s
#                    all      0.637      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/30     0.457G     0.7903         16        224: 100% ━━━━━━━━━━━━ 50/50 19.8it/s 2.5s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 52.8it/s 0.1s
#                    all      0.637      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/30     0.457G     0.7214         16        224: 100% ━━━━━━━━━━━━ 50/50 18.7it/s 2.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 43.5it/s 0.1s
#                    all      0.688      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/30     0.457G     0.7076         16        224: 100% ━━━━━━━━━━━━ 50/50 18.2it/s 2.8s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 44.8it/s 0.1s
#                    all      0.587      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/30     0.465G     0.6444         16        224: 100% ━━━━━━━━━━━━ 50/50 18.2it/s 2.8s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 48.2it/s 0.1s
#                    all      0.663      0.975
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/30     0.465G      0.609         16        224: 100% ━━━━━━━━━━━━ 50/50 17.9it/s 2.8s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 38.2it/s 0.1s
#                    all      0.613       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/30     0.465G     0.5635         16        224: 100% ━━━━━━━━━━━━ 50/50 16.9it/s 3.0s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 37.7it/s 0.1s
#                    all       0.65      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/30     0.465G     0.5477         16        224: 100% ━━━━━━━━━━━━ 50/50 16.6it/s 3.0s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 50.2it/s 0.1s
#                    all        0.6      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/30     0.465G     0.5763         16        224: 100% ━━━━━━━━━━━━ 50/50 18.3it/s 2.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 50.8it/s 0.1s
#                    all      0.675       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       21/30     0.465G     0.5148         16        224: 100% ━━━━━━━━━━━━ 50/50 14.3it/s 3.5s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 40.5it/s 0.1s
#                    all      0.663      0.925
#
#       Epoch    GPU_mem       loss  Instances       Size
#       22/30     0.465G     0.5093         16        224: 100% ━━━━━━━━━━━━ 50/50 18.0it/s 2.8s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 47.4it/s 0.1s
#                    all      0.663      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#       23/30     0.475G     0.4784         16        224: 100% ━━━━━━━━━━━━ 50/50 17.1it/s 2.9s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 44.7it/s 0.1s
#                    all      0.625      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#       24/30     0.475G     0.4688         16        224: 100% ━━━━━━━━━━━━ 50/50 16.8it/s 3.0s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 53.1it/s 0.1s
#                    all      0.637      0.925
#
#       Epoch    GPU_mem       loss  Instances       Size
#       25/30     0.475G     0.4265         16        224: 100% ━━━━━━━━━━━━ 50/50 16.7it/s 3.0s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 47.8it/s 0.1s
#                    all       0.65      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#       26/30     0.475G     0.4403         16        224: 100% ━━━━━━━━━━━━ 50/50 17.8it/s 2.8s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 45.9it/s 0.1s
#                    all      0.663      0.962
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 16, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 26 epochs completed in 0.024 hours.
# Optimizer stripped from /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/runs/train_yolo11n-cls.pt/weights/last.pt, 3.2MB
# Optimizer stripped from /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/runs/train_yolo11n-cls.pt/weights/best.pt, 3.2MB
#
# Validating /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/runs/train_yolo11n-cls.pt/weights/best.pt...
# Ultralytics 8.3.237 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce GTX 1660 Ti, 6144MiB)
# YOLO11n-cls summary (fused): 47 layers, 1,536,272 parameters, 0 gradients, 3.2 GFLOPs
# WARNING ⚠️ Dataset 'split=val' not found, using 'split=test' instead.
# train: /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/dataset/train... found 800 images in 8 classes ✅
# val: /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/dataset/test... found 80 images in 8 classes ✅
# test: /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/dataset/test... found 80 images in 8 classes ✅
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 24.6it/s 0.1s
#                    all      0.663      0.975
# Speed: 0.1ms preprocess, 0.7ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/runs/train_yolo11n-cls.pt
#
#
# -------------------Modelo: yolo11s-cls.pt-------------------
#
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11s-cls.pt to 'yolo11s-cls.pt': 100% ━━━━━━━━━━━━ 13.0MB 45.1MB/s 0.3s0.2s<0.1s
# Ultralytics 8.3.237 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce GTX 1660 Ti, 6144MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/dataset, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train_yolo11s-cls.pt, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/runs/train_yolo11s-cls.pt, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/dataset/train... found 800 images in 8 classes ✅
# val: None...
# test: /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/dataset/test... found 80 images in 8 classes ✅
# Overriding model.yaml nc=80 with nc=8
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  10                  -1  1    668168  ultralytics.nn.modules.head.Classify         [512, 8]
# YOLO11s-cls summary: 86 layers, 5,453,256 parameters, 5,453,256 gradients, 12.1 GFLOPs
# Transferred 234/236 items from pretrained weights
# WARNING ⚠️ AMP: checks failed ❌. AMP training on NVIDIA GeForce GTX 1660 Ti GPU may cause NaN losses or zero-mAP results, so AMP will be disabled during training.
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4905.2±1326.0 MB/s, size: 240.3 KB)
# train: Scanning /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/dataset/train... 800 images, 0 corrupt: 100% ━━━━━━━━━━━━ 800/800 1.2Mit/s 0.0s0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 275.0±56.7 MB/s, size: 419.6 KB)
# val: Scanning /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/dataset/test... 80 images, 0 corrupt: 100% ━━━━━━━━━━━━ 80/80 57.3Kit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000833, momentum=0.9) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 8 dataloader workers
# Logging results to /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/runs/train_yolo11s-cls.pt
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/30     0.732G      2.014         16        224: 100% ━━━━━━━━━━━━ 50/50 6.4it/s 7.8s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 18.2it/s 0.2s.7s
#                    all        0.5       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/30     0.846G      1.518         16        224: 100% ━━━━━━━━━━━━ 50/50 16.0it/s 3.1s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 44.6it/s 0.1s
#                    all      0.613      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/30     0.846G      1.343         16        224: 100% ━━━━━━━━━━━━ 50/50 17.0it/s 2.9s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 45.1it/s 0.1s
#                    all       0.55      0.925
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/30     0.846G       1.25         16        224: 100% ━━━━━━━━━━━━ 50/50 16.5it/s 3.0s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 43.4it/s 0.1s
#                    all      0.613       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/30     0.863G      1.172         16        224: 100% ━━━━━━━━━━━━ 50/50 15.0it/s 3.3s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 43.1it/s 0.1s
#                    all        0.6      0.925
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/30      0.93G      1.113         16        224: 100% ━━━━━━━━━━━━ 50/50 17.1it/s 2.9s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 44.1it/s 0.1s
#                    all      0.562      0.887
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/30      0.93G      1.013         16        224: 100% ━━━━━━━━━━━━ 50/50 16.5it/s 3.0s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 44.6it/s 0.1s
#                    all      0.575       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/30      0.93G     0.8977         16        224: 100% ━━━━━━━━━━━━ 50/50 17.3it/s 2.9s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 42.4it/s 0.1s
#                    all      0.625       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/30     0.945G     0.9449         16        224: 100% ━━━━━━━━━━━━ 50/50 17.6it/s 2.8s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 38.6it/s 0.1s
#                    all      0.562      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/30     0.947G     0.7665         16        224: 100% ━━━━━━━━━━━━ 50/50 17.7it/s 2.8s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 44.1it/s 0.1s
#                    all      0.613      0.975
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/30     0.947G     0.7802         16        224: 100% ━━━━━━━━━━━━ 50/50 14.8it/s 3.4s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 37.4it/s 0.1s
#                    all       0.65      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/30     0.947G     0.7489         16        224: 100% ━━━━━━━━━━━━ 50/50 14.0it/s 3.6s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 43.2it/s 0.1s
#                    all      0.613      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/30     0.963G     0.6469         16        224: 100% ━━━━━━━━━━━━ 50/50 15.0it/s 3.3s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 34.3it/s 0.1s
#                    all      0.538       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/30     0.963G     0.5832         16        224: 100% ━━━━━━━━━━━━ 50/50 16.3it/s 3.1s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 44.3it/s 0.1s
#                    all      0.663      0.975
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/30     0.963G      0.576         16        224: 100% ━━━━━━━━━━━━ 50/50 17.4it/s 2.9s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 43.3it/s 0.1s
#                    all        0.6      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/30     0.963G     0.5153         16        224: 100% ━━━━━━━━━━━━ 50/50 17.1it/s 2.9s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 45.2it/s 0.1s
#                    all      0.587      0.975
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/30     0.963G     0.4852         16        224: 100% ━━━━━━━━━━━━ 50/50 17.1it/s 2.9s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 41.2it/s 0.1s
#                    all      0.613      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/30     0.963G     0.4213         16        224: 100% ━━━━━━━━━━━━ 50/50 14.7it/s 3.4s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 40.9it/s 0.1s
#                    all      0.613       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/30     0.963G     0.4073         16        224: 100% ━━━━━━━━━━━━ 50/50 16.3it/s 3.1s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 41.2it/s 0.1s
#                    all      0.637      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/30     0.963G      0.438         16        224: 100% ━━━━━━━━━━━━ 50/50 15.6it/s 3.2s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 35.2it/s 0.1s
#                    all      0.663      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#       21/30     0.963G     0.3841         16        224: 100% ━━━━━━━━━━━━ 50/50 13.1it/s 3.8s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 41.8it/s 0.1s
#                    all      0.613      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#       22/30     0.963G     0.3335         16        224: 100% ━━━━━━━━━━━━ 50/50 13.2it/s 3.8s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 30.4it/s 0.1s
#                    all        0.6       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       23/30     0.963G     0.3392         16        224: 100% ━━━━━━━━━━━━ 50/50 13.8it/s 3.6s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 35.4it/s 0.1s
#                    all      0.663      0.925
#
#       Epoch    GPU_mem       loss  Instances       Size
#       24/30     0.963G     0.3306         16        224: 100% ━━━━━━━━━━━━ 50/50 13.9it/s 3.6s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 40.4it/s 0.1s
#                    all      0.663      0.925
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 14, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 24 epochs completed in 0.025 hours.
# Optimizer stripped from /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/runs/train_yolo11s-cls.pt/weights/last.pt, 11.0MB
# Optimizer stripped from /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/runs/train_yolo11s-cls.pt/weights/best.pt, 11.0MB
#
# Validating /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/runs/train_yolo11s-cls.pt/weights/best.pt...
# Ultralytics 8.3.237 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce GTX 1660 Ti, 6144MiB)
# YOLO11s-cls summary (fused): 47 layers, 5,444,376 parameters, 0 gradients, 12.0 GFLOPs
# WARNING ⚠️ Dataset 'split=val' not found, using 'split=test' instead.
# train: /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/dataset/train... found 800 images in 8 classes ✅
# val: /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/dataset/test... found 80 images in 8 classes ✅
# test: /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/dataset/test... found 80 images in 8 classes ✅
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 27.8it/s 0.1s
#                    all      0.663      0.975
# Speed: 0.1ms preprocess, 1.0ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/runs/train_yolo11s-cls.pt
#
#
# -------------------Modelo: yolo11m-cls.pt-------------------
#
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11m-cls.pt to 'yolo11m-cls.pt': 100% ━━━━━━━━━━━━ 22.4MB 42.5MB/s 0.5s0.5s<0.1s
# Ultralytics 8.3.237 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce GTX 1660 Ti, 6144MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/dataset, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11m-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train_yolo11m-cls.pt, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/runs/train_yolo11m-cls.pt, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/dataset/train... found 800 images in 8 classes ✅
# val: None...
# test: /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/dataset/test... found 80 images in 8 classes ✅
# Overriding model.yaml nc=80 with nc=8
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  10                  -1  1    668168  ultralytics.nn.modules.head.Classify         [512, 8]
# YOLO11m-cls summary: 106 layers, 10,363,464 parameters, 10,363,464 gradients, 39.6 GFLOPs
# Transferred 294/296 items from pretrained weights
# WARNING ⚠️ AMP: checks failed ❌. AMP training on NVIDIA GeForce GTX 1660 Ti GPU may cause NaN losses or zero-mAP results, so AMP will be disabled during training.
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 5988.4±1952.4 MB/s, size: 240.3 KB)
# train: Scanning /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/dataset/train... 800 images, 0 corrupt: 100% ━━━━━━━━━━━━ 800/800 1.4Mit/s 0.0s0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 609.4±66.2 MB/s, size: 419.6 KB)
# val: Scanning /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/dataset/test... 80 images, 0 corrupt: 100% ━━━━━━━━━━━━ 80/80 61.7Kit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000833, momentum=0.9) with parameter groups 49 weight(decay=0.0), 50 weight(decay=0.0005), 50 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 8 dataloader workers
# Logging results to /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/runs/train_yolo11m-cls.pt
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/30      2.57G      1.972         16        224: 100% ━━━━━━━━━━━━ 50/50 5.3it/s 9.4s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 19.2it/s 0.2s.2s
#                    all      0.438      0.913
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/30      3.77G      1.517         16        224: 100% ━━━━━━━━━━━━ 50/50 6.8it/s 7.3s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 19.4it/s 0.2s.2s
#                    all      0.562          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/30      2.61G      1.384         16        224: 100% ━━━━━━━━━━━━ 50/50 6.0it/s 8.3s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 19.1it/s 0.2s.2s
#                    all      0.475      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/30      2.63G       1.35         16        224: 100% ━━━━━━━━━━━━ 50/50 6.7it/s 7.4s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 19.6it/s 0.2s.2s
#                    all      0.538      0.913
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/30      2.63G      1.224         16        224: 100% ━━━━━━━━━━━━ 50/50 7.0it/s 7.1s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 20.6it/s 0.1s.2s
#                    all      0.538       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/30      2.63G      1.193         16        224: 100% ━━━━━━━━━━━━ 50/50 7.1it/s 7.0s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 20.8it/s 0.1s.2s
#                    all      0.562      0.925
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/30      2.63G      1.115         16        224: 100% ━━━━━━━━━━━━ 50/50 7.2it/s 7.0s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 20.1it/s 0.1s.2s
#                    all       0.65      0.925
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/30      2.63G      1.103         16        224: 100% ━━━━━━━━━━━━ 50/50 7.2it/s 6.9s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 20.7it/s 0.1s.2s
#                    all       0.55      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/30      2.63G      1.029         16        224: 100% ━━━━━━━━━━━━ 50/50 7.1it/s 7.1s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 20.5it/s 0.1s.2s
#                    all      0.562       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/30      2.63G     0.9299         16        224: 100% ━━━━━━━━━━━━ 50/50 7.1it/s 7.0s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 20.6it/s 0.1s.2s
#                    all      0.575       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/30      2.63G     0.8504         16        224: 100% ━━━━━━━━━━━━ 50/50 7.1it/s 7.1s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 19.7it/s 0.2s.2s
#                    all      0.613      0.925
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/30      2.63G     0.8443         16        224: 100% ━━━━━━━━━━━━ 50/50 7.0it/s 7.2s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 19.6it/s 0.2s.2s
#                    all      0.663      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/30      2.63G     0.6869         16        224: 100% ━━━━━━━━━━━━ 50/50 7.0it/s 7.2s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 20.0it/s 0.2s.2s
#                    all       0.65      0.925
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/30      2.63G     0.6616         16        224: 100% ━━━━━━━━━━━━ 50/50 6.9it/s 7.3s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 18.2it/s 0.2s.2s
#                    all      0.587      0.913
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/30      2.65G     0.6525         16        224: 100% ━━━━━━━━━━━━ 50/50 6.8it/s 7.3s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 19.4it/s 0.2s.2s
#                    all      0.663      0.925
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/30      2.68G     0.6098         16        224: 100% ━━━━━━━━━━━━ 50/50 6.7it/s 7.5s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 19.7it/s 0.2s.2s
#                    all      0.712       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/30      3.87G     0.5474         16        224: 100% ━━━━━━━━━━━━ 50/50 6.8it/s 7.4s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 18.2it/s 0.2s.2s
#                    all       0.65      0.913
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/30       2.8G     0.5175         16        224: 100% ━━━━━━━━━━━━ 50/50 6.6it/s 7.6s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 19.5it/s 0.2s.2s
#                    all      0.675      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/30       2.8G     0.4464         16        224: 100% ━━━━━━━━━━━━ 50/50 7.0it/s 7.2s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 19.9it/s 0.2s.2s
#                    all      0.663       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/30       2.8G     0.5071         16        224: 100% ━━━━━━━━━━━━ 50/50 7.1it/s 7.1s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 19.1it/s 0.2s.2s
#                    all      0.675       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       21/30       2.8G     0.4483         16        224: 100% ━━━━━━━━━━━━ 50/50 6.4it/s 7.8s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 19.4it/s 0.2s.2s
#                    all      0.625       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       22/30       2.8G      0.387         16        224: 100% ━━━━━━━━━━━━ 50/50 7.0it/s 7.2s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 20.2it/s 0.1s.2s
#                    all      0.712      0.975
#
#       Epoch    GPU_mem       loss  Instances       Size
#       23/30       2.8G     0.4004         16        224: 100% ━━━━━━━━━━━━ 50/50 7.0it/s 7.1s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 20.1it/s 0.1s.2s
#                    all       0.65      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#       24/30       2.8G     0.3203         16        224: 100% ━━━━━━━━━━━━ 50/50 7.0it/s 7.1s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 19.1it/s 0.2s.2s
#                    all      0.725      0.975
#
#       Epoch    GPU_mem       loss  Instances       Size
#       25/30       2.8G     0.2555         16        224: 100% ━━━━━━━━━━━━ 50/50 6.9it/s 7.2s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 19.8it/s 0.2s.2s
#                    all      0.625       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       26/30       2.8G      0.329         16        224: 100% ━━━━━━━━━━━━ 50/50 7.0it/s 7.2s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 20.2it/s 0.1s.2s
#                    all      0.637      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#       27/30       2.8G     0.2896         16        224: 100% ━━━━━━━━━━━━ 50/50 7.0it/s 7.1s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 20.3it/s 0.1s.2s
#                    all      0.663      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#       28/30       2.8G      0.253         16        224: 100% ━━━━━━━━━━━━ 50/50 7.1it/s 7.1s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 20.2it/s 0.1s.2s
#                    all      0.712       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       29/30      2.82G     0.2441         16        224: 100% ━━━━━━━━━━━━ 50/50 7.0it/s 7.2s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 19.7it/s 0.2s.2s
#                    all      0.675      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#       30/30      2.84G     0.2153         16        224: 100% ━━━━━━━━━━━━ 50/50 7.0it/s 7.2s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 20.1it/s 0.1s.2s
#                    all      0.688       0.95
#
# 30 epochs completed in 0.066 hours.
# Optimizer stripped from /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/runs/train_yolo11m-cls.pt/weights/last.pt, 20.9MB
# Optimizer stripped from /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/runs/train_yolo11m-cls.pt/weights/best.pt, 20.9MB
#
# Validating /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/runs/train_yolo11m-cls.pt/weights/best.pt...
# Ultralytics 8.3.237 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce GTX 1660 Ti, 6144MiB)
# YOLO11m-cls summary (fused): 57 layers, 10,351,880 parameters, 0 gradients, 39.3 GFLOPs
# WARNING ⚠️ Dataset 'split=val' not found, using 'split=test' instead.
# train: /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/dataset/train... found 800 images in 8 classes ✅
# val: /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/dataset/test... found 80 images in 8 classes ✅
# test: /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/dataset/test... found 80 images in 8 classes ✅
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 17.0it/s 0.2s.2s
#                    all      0.725      0.975
# Speed: 0.3ms preprocess, 1.8ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /home/carlos/3sw/aprendizaje/practicas-aprendizaje/practica4/runs/train_yolo11m-cls.pt
