# %% [markdown]
# En este Script se entrena un modelo con los conjuntos de datos train y test anteriores, y se guardan gráficos sobre dicho proceso, para analizar el rendimiento.
#
# Primero, debemos importar las librerías necesarias.

# %%
import os
from ultralytics import YOLO
import torch

# Comprobamos si Cuda está disponible, para poder entrenar en GPU
print(f"Versión de PyTorch: {torch.__version__}")
print(f"¿CUDA disponible? {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"Nombre de la GPU: {torch.cuda.get_device_name(0)}")
else:
    print(f"Debes instalar la versión de cuda correspondiente en https://pytorch.org/get-started/locally/")
# Out:
# Versión de PyTorch: 2.9.1+cu130
# ¿CUDA disponible? True
# Nombre de la GPU: NVIDIA GeForce RTX 4060 Laptop GPU

# %%
cwd = os.getcwd()
DATASET_PATH = os.path.join(cwd, "dataset")

models_to_train = ["yolo11n-cls.pt", "yolo11s-cls.pt", "yolo11m-cls.pt"]

EPOCHS = 30         # Número de pasadas por el dataset
IMGSZ = 224         # Tamaño de imagen
BATCH_SIZE = 16     
PATIENCE = 10       # Detener si no mejora tras 10 épocas
PROJECT_NAME = "runs" # Carpeta donde se guardarán los resultados

# %%
for model_name in models_to_train:
    run_name = f'train_{model_name}'
    
    print(f"\n\n-------------------Modelo: {model_name}-------------------\n")
    
    model = YOLO(model_name) # Cargamos el modelo
    
    model.train(
        data=DATASET_PATH,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=BATCH_SIZE,
        patience=PATIENCE, 
        project=PROJECT_NAME, # Crea la ruta: runs/train_n/ por ejemplo
        name=run_name,
        device=0, # Utilizamos la GPU
        verbose=True
    )
# Out:
# -------------------Modelo: yolo11n-cls.pt-------------------
#
# New https://pypi.org/project/ultralytics/8.3.237 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.235  Python-3.13.7 torch-2.9.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=c:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\dataset, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train_yolo11n-cls.pt2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\runs\train_yolo11n-cls.pt2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\dataset\train... found 800 images in 8 classes
# val: None...
# test: C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\dataset\test... found 80 images in 8 classes
# Overriding model.yaml nc=80 with nc=8
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  10                  -1  1    340488  ultralytics.nn.modules.head.Classify         [256, 8]
# YOLO11n-cls summary: 86 layers, 1,541,352 parameters, 1,541,352 gradients, 3.3 GFLOPs
# Transferred 234/236 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 40.9MB/s 0.1s.1s<0.1s
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 15.63.4 MB/s, size: 240.3 KB)
# train: Scanning C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\dataset\train... 800 images, 0 corrupt: 100% ━━━━━━━━━━━━ 800/800 419.2it/s 1.9s0.0s
# train: New cache created: C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\dataset\train.cache
# val: Fast image access  (ping: 0.00.0 ms, read: 329.6629.1 MB/s, size: 419.6 KB)
# val: Scanning C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\dataset\test... 80 images, 0 corrupt: 100% ━━━━━━━━━━━━ 80/80 495.9it/s 0.2s0.2s
# val: New cache created: C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\dataset\test.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000833, momentum=0.9) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 8 dataloader workers
# Logging results to C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\runs\train_yolo11n-cls.pt2
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
# Downloading https://ultralytics.com/assets/Arial.ttf to 'C:\Users\gonza\AppData\Roaming\Ultralytics\Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 13.3MB/s 0.1s
#        1/30     0.279G      2.099         16        224: 100% ━━━━━━━━━━━━ 50/50 9.2it/s 5.5s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 3.8it/s 0.8s5.1s
#                    all        0.5      0.925
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/30     0.289G      1.681         16        224: 100% ━━━━━━━━━━━━ 50/50 21.5it/s 2.3s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 54.9it/s 0.1s
#                    all      0.512      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/30     0.297G      1.452         16        224: 100% ━━━━━━━━━━━━ 50/50 21.6it/s 2.3s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 79.8it/s 0.0s
#                    all      0.625      0.975
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/30     0.307G      1.379         16        224: 100% ━━━━━━━━━━━━ 50/50 22.3it/s 2.2s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 61.5it/s 0.0s
#                    all      0.587      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/30     0.314G      1.244         16        224: 100% ━━━━━━━━━━━━ 50/50 23.5it/s 2.1s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 70.3it/s 0.0s
#                    all      0.587       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/30     0.324G      1.141         16        224: 100% ━━━━━━━━━━━━ 50/50 21.3it/s 2.3s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 65.4it/s 0.0s
#                    all      0.625      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/30     0.332G       1.14         16        224: 100% ━━━━━━━━━━━━ 50/50 22.5it/s 2.2s0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 61.1it/s 0.0s
#                    all       0.55      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/30     0.342G      1.045         16        224: 100% ━━━━━━━━━━━━ 50/50 21.0it/s 2.4s0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 51.0it/s 0.1s
#                    all        0.6      0.988
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/30      0.35G      0.998         16        224: 100% ━━━━━━━━━━━━ 50/50 21.3it/s 2.3s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 56.6it/s 0.1s
#                    all      0.625       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/30     0.357G     0.8806         16        224: 100% ━━━━━━━━━━━━ 50/50 21.0it/s 2.4s0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 60.8it/s 0.0s
#                    all      0.637       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/30     0.367G     0.9025         16        224: 100% ━━━━━━━━━━━━ 50/50 21.7it/s 2.3s0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 58.3it/s 0.1s
#                    all      0.663      0.988
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/30     0.377G     0.8127         16        224: 100% ━━━━━━━━━━━━ 50/50 21.3it/s 2.3s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 52.6it/s 0.1s
#                    all      0.637      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/30     0.385G      0.775         16        224: 100% ━━━━━━━━━━━━ 50/50 21.7it/s 2.3s0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 64.0it/s 0.0s
#                    all      0.637      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/30     0.393G     0.6793         16        224: 100% ━━━━━━━━━━━━ 50/50 21.7it/s 2.3s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 53.5it/s 0.1s
#                    all      0.637      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/30     0.402G     0.6852         16        224: 100% ━━━━━━━━━━━━ 50/50 21.3it/s 2.3s0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 68.0it/s 0.0s
#                    all      0.675      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/30      0.41G     0.6328         16        224: 100% ━━━━━━━━━━━━ 50/50 22.7it/s 2.2s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 50.8it/s 0.1s
#                    all      0.587      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/30      0.42G     0.6062         16        224: 100% ━━━━━━━━━━━━ 50/50 21.7it/s 2.3s0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 55.9it/s 0.1s
#                    all      0.625      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/30     0.428G       0.58         16        224: 100% ━━━━━━━━━━━━ 50/50 22.5it/s 2.2s0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 52.4it/s 0.1s
#                    all       0.65       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/30     0.438G     0.5502         16        224: 100% ━━━━━━━━━━━━ 50/50 21.6it/s 2.3s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 49.4it/s 0.1s
#                    all      0.587      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/30     0.445G     0.5785         16        224: 100% ━━━━━━━━━━━━ 50/50 21.4it/s 2.3s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 55.6it/s 0.1s
#                    all       0.65      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#       21/30     0.455G     0.5254         16        224: 100% ━━━━━━━━━━━━ 50/50 20.4it/s 2.5s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 60.8it/s 0.0s
#                    all        0.6       0.95
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 11, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 21 epochs completed in 0.022 hours.
# Optimizer stripped from C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\runs\train_yolo11n-cls.pt2\weights\last.pt, 3.2MB
# Optimizer stripped from C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\runs\train_yolo11n-cls.pt2\weights\best.pt, 3.2MB
#
# Validating C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\runs\train_yolo11n-cls.pt2\weights\best.pt...
# Ultralytics 8.3.235  Python-3.13.7 torch-2.9.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# YOLO11n-cls summary (fused): 47 layers, 1,536,272 parameters, 0 gradients, 3.2 GFLOPs
# WARNING Dataset 'split=val' not found, using 'split=test' instead.
# train: C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\dataset\train... found 800 images in 8 classes
# val: C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\dataset\test... found 80 images in 8 classes
# test: C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\dataset\test... found 80 images in 8 classes
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 53.0it/s 0.1s
#                    all      0.663      0.988
# Speed: 0.1ms preprocess, 0.4ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\runs\train_yolo11n-cls.pt2
#
#
# -------------------Modelo: yolo11s-cls.pt-------------------
#
# New https://pypi.org/project/ultralytics/8.3.237 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.235  Python-3.13.7 torch-2.9.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=c:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\dataset, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train_yolo11s-cls.pt2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\runs\train_yolo11s-cls.pt2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\dataset\train... found 800 images in 8 classes
# val: None...
# test: C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\dataset\test... found 80 images in 8 classes
# Overriding model.yaml nc=80 with nc=8
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  10                  -1  1    668168  ultralytics.nn.modules.head.Classify         [512, 8]
# YOLO11s-cls summary: 86 layers, 5,453,256 parameters, 5,453,256 gradients, 12.1 GFLOPs
# Transferred 234/236 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 2449.1747.6 MB/s, size: 240.3 KB)
# train: Scanning C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\dataset\train... 800 images, 0 corrupt: 100% ━━━━━━━━━━━━ 800/800 1.5Mit/s 0.0s0s
# val: Fast image access  (ping: 0.00.0 ms, read: 1435.2277.6 MB/s, size: 419.6 KB)
# val: Scanning C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\dataset\test... 80 images, 0 corrupt: 100% ━━━━━━━━━━━━ 80/80 118.3Kit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000833, momentum=0.9) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 8 dataloader workers
# Logging results to C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\runs\train_yolo11s-cls.pt2
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/30     0.555G      2.024         16        224: 100% ━━━━━━━━━━━━ 50/50 9.2it/s 5.5s<0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 8.6it/s 0.4s2.1s
#                    all      0.463       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/30     0.637G      1.531         16        224: 100% ━━━━━━━━━━━━ 50/50 16.1it/s 3.1s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 52.9it/s 0.1s
#                    all      0.538      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/30     0.637G       1.34         16        224: 100% ━━━━━━━━━━━━ 50/50 21.3it/s 2.3s0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 55.3it/s 0.1s
#                    all      0.475      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/30     0.637G      1.239         16        224: 100% ━━━━━━━━━━━━ 50/50 21.3it/s 2.3s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 56.7it/s 0.1s
#                    all       0.55       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/30     0.637G      1.154         16        224: 100% ━━━━━━━━━━━━ 50/50 22.2it/s 2.3s0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 49.9it/s 0.1s
#                    all      0.538      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/30     0.637G      1.056         16        224: 100% ━━━━━━━━━━━━ 50/50 21.9it/s 2.3s0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 48.3it/s 0.1s
#                    all      0.525        0.9
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/30     0.641G      1.056         16        224: 100% ━━━━━━━━━━━━ 50/50 21.7it/s 2.3s0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 82.2it/s 0.0s
#                    all      0.538      0.887
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/30     0.641G       0.89         16        224: 100% ━━━━━━━━━━━━ 50/50 21.5it/s 2.3s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 69.3it/s 0.0s
#                    all        0.6      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/30     0.643G     0.8609         16        224: 100% ━━━━━━━━━━━━ 50/50 22.2it/s 2.2s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 83.8it/s 0.0s
#                    all      0.575       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/30     0.658G     0.7761         16        224: 100% ━━━━━━━━━━━━ 50/50 22.8it/s 2.2s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 54.6it/s 0.1s
#                    all      0.587        0.9
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/30     0.658G     0.7206         16        224: 100% ━━━━━━━━━━━━ 50/50 22.6it/s 2.2s0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 59.1it/s 0.1s
#                    all        0.6       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/30     0.658G     0.7375         16        224: 100% ━━━━━━━━━━━━ 50/50 23.1it/s 2.2s0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 54.8it/s 0.1s
#                    all        0.6      0.913
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/30     0.658G     0.6603         16        224: 100% ━━━━━━━━━━━━ 50/50 22.6it/s 2.2s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 64.2it/s 0.0s
#                    all      0.575      0.925
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/30     0.658G     0.5917         16        224: 100% ━━━━━━━━━━━━ 50/50 21.8it/s 2.3s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 84.9it/s 0.0s
#                    all      0.613      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/30     0.658G     0.5305         16        224: 100% ━━━━━━━━━━━━ 50/50 21.4it/s 2.3s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 84.6it/s 0.0s
#                    all        0.6       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/30     0.658G     0.5188         16        224: 100% ━━━━━━━━━━━━ 50/50 21.7it/s 2.3s0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 70.4it/s 0.0s
#                    all      0.587       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/30     0.658G     0.4789         16        224: 100% ━━━━━━━━━━━━ 50/50 21.7it/s 2.3s0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 57.3it/s 0.1s
#                    all        0.5      0.925
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/30     0.658G     0.3831         16        224: 100% ━━━━━━━━━━━━ 50/50 21.6it/s 2.3s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 64.2it/s 0.0s
#                    all        0.6      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/30     0.658G     0.3879         16        224: 100% ━━━━━━━━━━━━ 50/50 22.4it/s 2.2s0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 61.0it/s 0.0s
#                    all      0.613      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/30     0.658G     0.4278         16        224: 100% ━━━━━━━━━━━━ 50/50 22.2it/s 2.3s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 51.0it/s 0.1s
#                    all      0.637      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#       21/30     0.658G     0.3547         16        224: 100% ━━━━━━━━━━━━ 50/50 20.6it/s 2.4s0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 53.7it/s 0.1s
#                    all      0.562      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#       22/30      0.66G     0.3393         16        224: 100% ━━━━━━━━━━━━ 50/50 21.9it/s 2.3s0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 75.2it/s 0.0s
#                    all        0.6      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#       23/30     0.662G     0.3236         16        224: 100% ━━━━━━━━━━━━ 50/50 22.6it/s 2.2s0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 60.2it/s 0.0s
#                    all      0.613      0.925
#
#       Epoch    GPU_mem       loss  Instances       Size
#       24/30     0.678G     0.3262         16        224: 100% ━━━━━━━━━━━━ 50/50 22.7it/s 2.2s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 72.8it/s 0.0s
#                    all      0.663      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#       25/30     0.703G     0.2748         16        224: 100% ━━━━━━━━━━━━ 50/50 23.3it/s 2.2s0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 53.7it/s 0.1s
#                    all        0.6      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#       26/30     0.705G     0.2749         16        224: 100% ━━━━━━━━━━━━ 50/50 22.2it/s 2.3s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 80.9it/s 0.0s
#                    all      0.587      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#       27/30     0.719G     0.2018         16        224: 100% ━━━━━━━━━━━━ 50/50 24.1it/s 2.1s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 51.4it/s 0.1s
#                    all       0.55      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#       28/30     0.719G     0.2062         16        224: 100% ━━━━━━━━━━━━ 50/50 22.8it/s 2.2s0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 58.8it/s 0.1s
#                    all        0.6      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#       29/30     0.723G      0.209         16        224: 100% ━━━━━━━━━━━━ 50/50 23.5it/s 2.1s0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 48.6it/s 0.1s
#                    all        0.6      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#       30/30     0.762G      0.197         16        224: 100% ━━━━━━━━━━━━ 50/50 22.7it/s 2.2s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 59.9it/s 0.1s
#                    all        0.6      0.938
#
# 30 epochs completed in 0.029 hours.
# Optimizer stripped from C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\runs\train_yolo11s-cls.pt2\weights\last.pt, 11.0MB
# Optimizer stripped from C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\runs\train_yolo11s-cls.pt2\weights\best.pt, 11.0MB
#
# Validating C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\runs\train_yolo11s-cls.pt2\weights\best.pt...
# Ultralytics 8.3.235  Python-3.13.7 torch-2.9.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# YOLO11s-cls summary (fused): 47 layers, 5,444,376 parameters, 0 gradients, 12.0 GFLOPs
# WARNING Dataset 'split=val' not found, using 'split=test' instead.
# train: C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\dataset\train... found 800 images in 8 classes
# val: C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\dataset\test... found 80 images in 8 classes
# test: C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\dataset\test... found 80 images in 8 classes
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 58.1it/s 0.1s
#                    all      0.663      0.938
# Speed: 0.1ms preprocess, 0.4ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\runs\train_yolo11s-cls.pt2
#
#
# -------------------Modelo: yolo11m-cls.pt-------------------
#
# New https://pypi.org/project/ultralytics/8.3.237 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.235  Python-3.13.7 torch-2.9.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=c:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\dataset, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11m-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train_yolo11m-cls.pt2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\runs\train_yolo11m-cls.pt2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\dataset\train... found 800 images in 8 classes
# val: None...
# test: C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\dataset\test... found 80 images in 8 classes
# Overriding model.yaml nc=80 with nc=8
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  10                  -1  1    668168  ultralytics.nn.modules.head.Classify         [512, 8]
# YOLO11m-cls summary: 106 layers, 10,363,464 parameters, 10,363,464 gradients, 39.6 GFLOPs
# Transferred 294/296 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 1757.1416.7 MB/s, size: 240.3 KB)
# train: Scanning C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\dataset\train... 800 images, 0 corrupt: 100% ━━━━━━━━━━━━ 800/800 2.3Mit/s 0.0s0s
# val: Fast image access  (ping: 0.00.0 ms, read: 2771.2523.7 MB/s, size: 419.6 KB)
# val: Scanning C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\dataset\test... 80 images, 0 corrupt: 100% ━━━━━━━━━━━━ 80/80 169.9Kit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000833, momentum=0.9) with parameter groups 49 weight(decay=0.0), 50 weight(decay=0.0005), 50 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 8 dataloader workers
# Logging results to C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\runs\train_yolo11m-cls.pt2
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/30     0.973G      1.979         16        224: 100% ━━━━━━━━━━━━ 50/50 10.0it/s 5.0s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 11.8it/s 0.3s.2s
#                    all      0.425      0.875
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/30      1.15G      1.531         16        224: 100% ━━━━━━━━━━━━ 50/50 15.3it/s 3.3s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 45.5it/s 0.1s
#                    all      0.575      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/30      1.18G      1.386         16        224: 100% ━━━━━━━━━━━━ 50/50 20.2it/s 2.5s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 54.8it/s 0.1s
#                    all      0.525      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/30      1.29G        1.3         16        224: 100% ━━━━━━━━━━━━ 50/50 19.4it/s 2.6s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 51.6it/s 0.1s
#                    all        0.5      0.925
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/30      1.29G      1.253         16        224: 100% ━━━━━━━━━━━━ 50/50 19.6it/s 2.6s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 55.8it/s 0.1s
#                    all      0.538      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/30      1.31G      1.129         16        224: 100% ━━━━━━━━━━━━ 50/50 19.0it/s 2.6s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 53.6it/s 0.1s
#                    all      0.575      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/30      1.31G      1.075         16        224: 100% ━━━━━━━━━━━━ 50/50 19.0it/s 2.6s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 54.7it/s 0.1s
#                    all      0.538      0.925
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/30      1.31G      1.037         16        224: 100% ━━━━━━━━━━━━ 50/50 18.5it/s 2.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 45.3it/s 0.1s
#                    all        0.6       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/30      1.31G      1.007         16        224: 100% ━━━━━━━━━━━━ 50/50 20.1it/s 2.5s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 49.0it/s 0.1s
#                    all       0.65      0.925
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/30      1.31G     0.8941         16        224: 100% ━━━━━━━━━━━━ 50/50 19.3it/s 2.6s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 48.7it/s 0.1s
#                    all        0.6        0.9
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/30      1.31G     0.8294         16        224: 100% ━━━━━━━━━━━━ 50/50 19.8it/s 2.5s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 48.9it/s 0.1s
#                    all        0.6       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/30      1.31G     0.7978         16        224: 100% ━━━━━━━━━━━━ 50/50 18.9it/s 2.6s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 50.7it/s 0.1s
#                    all      0.675       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/30      1.31G     0.7492         16        224: 100% ━━━━━━━━━━━━ 50/50 18.9it/s 2.6s0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 45.1it/s 0.1s
#                    all       0.55      0.938
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/30      1.31G     0.6183         16        224: 100% ━━━━━━━━━━━━ 50/50 18.6it/s 2.7s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 54.3it/s 0.1s
#                    all      0.613      0.962
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/30      1.31G     0.5541         16        224: 100% ━━━━━━━━━━━━ 50/50 19.8it/s 2.5s0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 43.9it/s 0.1s
#                    all      0.575       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/30      1.31G     0.5737         16        224: 100% ━━━━━━━━━━━━ 50/50 19.7it/s 2.5s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 55.1it/s 0.1s
#                    all      0.538       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/30      1.31G     0.5327         16        224: 100% ━━━━━━━━━━━━ 50/50 20.4it/s 2.5s0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 56.1it/s 0.1s
#                    all      0.675       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/30      1.34G     0.5041         16        224: 100% ━━━━━━━━━━━━ 50/50 19.4it/s 2.6s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 50.2it/s 0.1s
#                    all      0.637       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/30      1.34G     0.4188         16        224: 100% ━━━━━━━━━━━━ 50/50 19.6it/s 2.5s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 43.2it/s 0.1s
#                    all       0.65      0.975
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/30      1.34G     0.4647         16        224: 100% ━━━━━━━━━━━━ 50/50 19.5it/s 2.6s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 53.0it/s 0.1s
#                    all      0.625      0.975
#
#       Epoch    GPU_mem       loss  Instances       Size
#       21/30      1.34G     0.4412         16        224: 100% ━━━━━━━━━━━━ 50/50 16.6it/s 3.0s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 48.7it/s 0.1s
#                    all      0.613       0.95
#
#       Epoch    GPU_mem       loss  Instances       Size
#       22/30      1.34G     0.3655         16        224: 100% ━━━━━━━━━━━━ 50/50 19.7it/s 2.5s0.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 49.0it/s 0.1s
#                    all      0.637      0.988
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 12, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 22 epochs completed in 0.026 hours.
# Optimizer stripped from C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\runs\train_yolo11m-cls.pt2\weights\last.pt, 20.9MB
# Optimizer stripped from C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\runs\train_yolo11m-cls.pt2\weights\best.pt, 20.9MB
#
# Validating C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\runs\train_yolo11m-cls.pt2\weights\best.pt...
# Ultralytics 8.3.235  Python-3.13.7 torch-2.9.1+cu130 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# YOLO11m-cls summary (fused): 57 layers, 10,351,880 parameters, 0 gradients, 39.3 GFLOPs
# WARNING Dataset 'split=val' not found, using 'split=test' instead.
# train: C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\dataset\train... found 800 images in 8 classes
# val: C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\dataset\test... found 80 images in 8 classes
# test: C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\dataset\test... found 80 images in 8 classes
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 35.8it/s 0.1s
#                    all      0.637      0.988
# Speed: 0.1ms preprocess, 0.7ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to C:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\practica4\runs\train_yolo11m-cls.pt2
