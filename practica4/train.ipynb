# %% [markdown]
# En este Script se entrena un modelo con los conjuntos de datos train y test anteriores, y se guardan gráficos sobre dicho proceso, para analizar el rendimiento.
#
# Primero, debemos importar las librerías necesarias.

# %%
import os
from ultralytics import YOLO
import torch

# Comprobamos si Cuda está disponible, para poder entrenar en GPU
print(f"Versión de PyTorch: {torch.__version__}")
print(f"¿CUDA disponible? {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"Nombre de la GPU: {torch.cuda.get_device_name(0)}")
# Out:
# Versión de PyTorch: 2.9.1+cpu
# ¿CUDA disponible? False

# %%
cwd = os.getcwd()
DATASET_PATH = os.path.join(cwd, "dataset")

models_to_train = ["yolo11n-cls.pt", "yolo11s-cls.pt", "yolo11m-cls.pt"]

EPOCHS = 30         # Número de pasadas por el dataset
IMGSZ = 224         # Tamaño de imagen
BATCH_SIZE = 16     
PATIENCE = 10       # Detener si no mejora tras 10 épocas
PROJECT_NAME = "runs" # Carpeta donde se guardarán los resultados

# %%
for model_name in models_to_train:
    run_name = f'train_{model_name}'
    
    print(f"\n\n-------------------Modelo: {model_name}-------------------\n")
    
    model = YOLO(model_name) # Cargamos el modelo
    
    model.train(
        data=DATASET_PATH,
        epochs=EPOCHS,
        imgsz=IMGSZ,
        batch=BATCH_SIZE,
        patience=PATIENCE, 
        project=PROJECT_NAME, # Crea la ruta: runs/train_n/ por ejemplo
        name=run_name,
        device=0, # Utilizamos la GPU
        verbose=True
    )
# Out:
# -------------------Modelo: yolo11n-cls.pt-------------------
#
# New https://pypi.org/project/ultralytics/8.3.237 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.235  Python-3.13.7 torch-2.9.1+cpu
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 8
#       4 print(f"\n\n-------------------Modelo: {model_name}-------------------\n")
#       6 model = YOLO(model_name) # Cargamos el modelo
# ----> 8 model.train(
#       9     data=DATASET_PATH,
#      10     epochs=EPOCHS,
#      11     imgsz=IMGSZ,
#      12     batch=BATCH_SIZE,
#      13     patience=PATIENCE,
#      14     project=PROJECT_NAME, # Crea la ruta: runs/train_n/ por ejemplo
#      15     name=run_name,
#      16     device=0, # Utilizamos la GPU
#      17     verbose=True
#      18 )
#
# File c:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\venv\Lib\site-packages\ultralytics\engine\model.py:768, in Model.train(self, trainer, **kwargs)
#     765 if args.get("resume"):
#     766     args["resume"] = self.ckpt_path
# --> 768 self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#     769 if not args.get("resume"):  # manually set model only if not resuming
#     770     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#
# File c:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\venv\Lib\site-packages\ultralytics\models\yolo\classify\train.py:65, in ClassificationTrainer.__init__(self, cfg, overrides, _callbacks)
#      63 if overrides.get("imgsz") is None:
#      64     overrides["imgsz"] = 224
# ---> 65 super().__init__(cfg, overrides, _callbacks)
#
# File c:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\venv\Lib\site-packages\ultralytics\engine\trainer.py:126, in BaseTrainer.__init__(self, cfg, overrides, _callbacks)
#     124 self.args = get_cfg(cfg, overrides)
#     125 self.check_resume(overrides)
# --> 126 self.device = select_device(self.args.device)
#     127 # Update "-1" devices so post-training val does not repeat search
#     128 self.args.device = os.getenv("CUDA_VISIBLE_DEVICES") if "cuda" in str(self.device) else str(self.device)
#
# File c:\Users\gonza\Desktop\universidad\Malaga\Tercero\Aprendizaje_Automatico\practicas-aprendizaje\venv\Lib\site-packages\ultralytics\utils\torch_utils.py:198, in select_device(device, newline, verbose)
#     191         LOGGER.info(s)
#     192         install = (
#     193             "See https://pytorch.org/get-started/locally/ for up-to-date torch install instructions if no "
#     194             "CUDA devices are seen by torch.\n"
#     195             if torch.cuda.device_count() == 0
#     196             else ""
#     197         )
# --> 198         raise ValueError(
#     199             f"Invalid CUDA 'device={device}' requested."
#     200             f" Use 'device=cpu' or pass valid CUDA device(s) if available,"
#     201             f" i.e. 'device=0' or 'device=0,1,2,3' for Multi-GPU.\n"
#     202             f"\ntorch.cuda.is_available(): {torch.cuda.is_available()}"
#     203             f"\ntorch.cuda.device_count(): {torch.cuda.device_count()}"
#     204             f"\nos.environ['CUDA_VISIBLE_DEVICES']: {visible}\n"
#     205             f"{install}"
#     206         )
#     208 if not cpu and not mps and torch.cuda.is_available():  # prefer GPU if available
#     209     devices = device.split(",") if device else "0"  # i.e. "0,1" -> ["0", "1"]
#
# ValueError: Invalid CUDA 'device=0' requested. Use 'device=cpu' or pass valid CUDA device(s) if available, i.e. 'device=0' or 'device=0,1,2,3' for Multi-GPU.
#
# torch.cuda.is_available(): False
# torch.cuda.device_count(): 0
# os.environ['CUDA_VISIBLE_DEVICES']: 0
# See https://pytorch.org/get-started/locally/ for up-to-date torch install instructions if no CUDA devices are seen by torch.
