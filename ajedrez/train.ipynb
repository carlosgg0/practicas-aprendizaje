# %% [markdown]
# En este archivo se explica e implementa el proceso de entrenamiento de los modelos, que consiste basicamente en cargar los datos de entrenamiento y entrenar los modelos con dichos conjuntos. Para ello, además de las librerías dadas en clase, se utiliza *joblib* para exportar los modelos.

# %%
import pandas as pd
import numpy as np
import os
import joblib
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# Definimos todos los métodos, y versiones del conjunto de datos que vamos a utilizar

# %%
METHODS = ['knn', 'svm', 'naive_bayes', 'random_forest']
SETS = [
    'normalized', 'normalized_pca_80', 'normalized_pca_95',
    'original', 'original_pca_80', 'original_pca_95',
    'standarized', 'standarized_pca_80', 'standarized_pca_95'
]

# %% [markdown]
# Creación de directorios necesarios

# %%
CWD = os.getcwd()
MODELS_PATH = os.path.join(CWD, "models")

try:
    os.mkdir(MODELS_PATH)
except FileExistsError:
    pass

# %% [markdown]
# ### Entrenamiento de modelos
# El primer paso es cargar el conjunto de entrenamiento. Después, entrenaremos un modelo con los datos cargados. Se implementa a continuación una función que entrena el modelo seleccionado mediante el parámetro $method$, utilizando los datos de entrenamiento de la versión y partición deseada con los parámetros $set$ y $fold$.

# %%
def genera_modelo(method: str, set: str, fold: str):
    """
        Entrena un modelo seleccionado, para la version del conjunto y la partición seleccionadas.
    
        Args:
            method: tipo de modelo
            set: version del conjunto de datos
            fold: particion (1 - 5)
                    
        Returns: 
            model_fitted: modelo entrenado con los conjuntos de datos
    """

    # Cargamos el conjunto de entrenamiento
    training_df = pd.read_csv(f"{set}/training{fold}_{set}.csv")

    X_train = training_df.iloc[:, :-1]
    y_train = training_df.iloc[:, -1] 

    # Generamos y entrenamos el modelo que corresponda
    if method == 'knn':                 # K-Nearest Neighbors (KNN)
        model_fitted = KNeighborsClassifier(n_neighbors=5)

    elif method == 'svm':               # Support Vector Machine (SVM)
        model_fitted = SVC(kernel='linear', random_state=42, probability=True)

    elif method == 'naive_bayes':       # Naive Bayes (Gaussian)
        model_fitted = GaussianNB()

    elif method == 'random_forest':     # Random Forest
        model_fitted = RandomForestClassifier(n_estimators=100, random_state=42)

    model_fitted.fit(X_train, y_train)

    # Guardamos el modelo entrenado para el conjunto y fold específicos
    model_name = f"{method}_{set}_{fold}.pkl"
    joblib.dump(model_fitted, os.path.join(MODELS_PATH, model_name))

# %% [markdown]
# ### Generación de modelos entrenados
# A continuación, para cada versión del conjunto de datos, se va a entrenar un modelo por cada método de los siguientes: K-NN, SVM, Naive Bayes y Random Forest.

# %%
for method in METHODS:
    for set in SETS:
        for fold in range(1, 6):
            print(f"Generando {method} sobre el conjunto {set} para el fold {fold}")
            genera_modelo(method, set, fold)
# Out:
# Generando knn sobre el conjunto normalized para el fold 1
# Generando knn sobre el conjunto normalized para el fold 2
# Generando knn sobre el conjunto normalized para el fold 3
# Generando knn sobre el conjunto normalized para el fold 4
# Generando knn sobre el conjunto normalized para el fold 5
# Generando knn sobre el conjunto normalized_pca_80 para el fold 1
# Generando knn sobre el conjunto normalized_pca_80 para el fold 2
# Generando knn sobre el conjunto normalized_pca_80 para el fold 3
# Generando knn sobre el conjunto normalized_pca_80 para el fold 4
# Generando knn sobre el conjunto normalized_pca_80 para el fold 5
# Generando knn sobre el conjunto normalized_pca_95 para el fold 1
# Generando knn sobre el conjunto normalized_pca_95 para el fold 2
# Generando knn sobre el conjunto normalized_pca_95 para el fold 3
# Generando knn sobre el conjunto normalized_pca_95 para el fold 4
# Generando knn sobre el conjunto normalized_pca_95 para el fold 5
# Generando knn sobre el conjunto original para el fold 1
# Generando knn sobre el conjunto original para el fold 2
# Generando knn sobre el conjunto original para el fold 3
# Generando knn sobre el conjunto original para el fold 4
# Generando knn sobre el conjunto original para el fold 5
# Generando knn sobre el conjunto original_pca_80 para el fold 1
# Generando knn sobre el conjunto original_pca_80 para el fold 2
# Generando knn sobre el conjunto original_pca_80 para el fold 3
# Generando knn sobre el conjunto original_pca_80 para el fold 4
# Generando knn sobre el conjunto original_pca_80 para el fold 5
# Generando knn sobre el conjunto original_pca_95 para el fold 1
# Generando knn sobre el conjunto original_pca_95 para el fold 2
# Generando knn sobre el conjunto original_pca_95 para el fold 3
# Generando knn sobre el conjunto original_pca_95 para el fold 4
# Generando knn sobre el conjunto original_pca_95 para el fold 5
# Generando knn sobre el conjunto standarized para el fold 1
# Generando knn sobre el conjunto standarized para el fold 2
# Generando knn sobre el conjunto standarized para el fold 3
# Generando knn sobre el conjunto standarized para el fold 4
# Generando knn sobre el conjunto standarized para el fold 5
# Generando knn sobre el conjunto standarized_pca_80 para el fold 1
# Generando knn sobre el conjunto standarized_pca_80 para el fold 2
# Generando knn sobre el conjunto standarized_pca_80 para el fold 3
# Generando knn sobre el conjunto standarized_pca_80 para el fold 4
# Generando knn sobre el conjunto standarized_pca_80 para el fold 5
# Generando knn sobre el conjunto standarized_pca_95 para el fold 1
# Generando knn sobre el conjunto standarized_pca_95 para el fold 2
# Generando knn sobre el conjunto standarized_pca_95 para el fold 3
# Generando knn sobre el conjunto standarized_pca_95 para el fold 4
# Generando knn sobre el conjunto standarized_pca_95 para el fold 5
# Generando svm sobre el conjunto normalized para el fold 1
# Generando svm sobre el conjunto normalized para el fold 2
# Generando svm sobre el conjunto normalized para el fold 3
# Generando svm sobre el conjunto normalized para el fold 4
# Generando svm sobre el conjunto normalized para el fold 5
# Generando svm sobre el conjunto normalized_pca_80 para el fold 1
# Generando svm sobre el conjunto normalized_pca_80 para el fold 2
# Generando svm sobre el conjunto normalized_pca_80 para el fold 3
# Generando svm sobre el conjunto normalized_pca_80 para el fold 4
# Generando svm sobre el conjunto normalized_pca_80 para el fold 5
# Generando svm sobre el conjunto normalized_pca_95 para el fold 1
# Generando svm sobre el conjunto normalized_pca_95 para el fold 2
# Generando svm sobre el conjunto normalized_pca_95 para el fold 3
# Generando svm sobre el conjunto normalized_pca_95 para el fold 4
# Generando svm sobre el conjunto normalized_pca_95 para el fold 5
# Generando svm sobre el conjunto original para el fold 1
